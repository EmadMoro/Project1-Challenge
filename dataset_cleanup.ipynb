# %%
import pandas as pd

# %%
new_df = pd.read_csv('Resources/autos_raw.csv')
new_df.head()
# Out:
#    index          dateCrawled                            name  seller  \
# 0      0  2016-03-24 11:52:17                      Golf_3_1.6  privat
# 1      1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat
# 2      2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat
# 3      3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat
# 4      4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat
#
#   offerType  price abtest vehicleType  yearOfRegistration    gearbox  ...  \
# 0   Angebot    480   test         NaN                1993    manuell  ...
# 1   Angebot  18300   test       coupe                2011    manuell  ...
# 2   Angebot   9800   test         suv                2004  automatik  ...
# 3   Angebot   1500   test  kleinwagen                2001    manuell  ...
# 4   Angebot   3600   test  kleinwagen                2008    manuell  ...
#
#    model kilometer  monthOfRegistration  fuelType       brand  \
# ...

# %%
new_df = new_df.drop(['abtest','index','offerType','monthOfRegistration',
                     'notRepairedDamage','nrOfPictures','postalCode',
                      'dateCreated','powerPS','seller','gearbox'], axis = 1)

new_df.head()
# Out:
#            dateCrawled                            name  price vehicleType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6    480         NaN
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  18300       coupe
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"   9800         suv
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER   1500  kleinwagen
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic   3600  kleinwagen
#
#    yearOfRegistration  model  kilometer fuelType       brand  \
# 0                1993   golf     150000   benzin  volkswagen
# 1                2011    NaN     125000   diesel        audi
# 2                2004  grand     125000   diesel        jeep
# 3                2001   golf     150000   benzin  volkswagen
# 4                2008  fabia      90000   diesel       skoda
#
#               lastSeen
# 0  2016-04-07 03:16:57
# 1  2016-04-07 01:46:50
# 2  2016-04-05 12:47:46
# 3  2016-03-17 17:40:17
# 4  2016-04-06 10:17:21

# %%
new_df.shape
# Out:
# (371528, 10)

# %%
new_df = new_df.replace('', 'NaN')
new_df = new_df.replace(' ', 'NaN')
new_df = new_df.dropna().reset_index(drop=True)
new_df.shape
# Out:
# (307122, 10)

# %%
new_df
# Out:
#                 dateCrawled  \
# 0       2016-03-14 12:52:21
# 1       2016-03-17 16:54:04
# 2       2016-03-31 17:25:20
# 3       2016-04-04 17:36:23
# 4       2016-04-01 20:48:51
# ...                     ...
# 307117  2016-03-27 20:36:20
# 307118  2016-03-05 19:56:21
# 307119  2016-03-19 18:57:12
# 307120  2016-03-20 19:41:08
# 307121  2016-03-07 19:39:19
#
#                                                      name  price vehicleType  \
# 0                          Jeep_Grand_Cherokee_"Overland"   9800         suv
# 1                                      GOLF_4_1_4__3TÜRER   1500  kleinwagen
# 2                          Skoda_Fabia_1.4_TDI_PD_Classic   3600  kleinwagen
# 3       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...    650   limousine
# 4                             Peugeot_206_CC_110_Platinum   2200      cabrio
# ...                                                   ...    ...         ...
# 307117                 Opel_Zafira_1.6_Elegance_TÜV_12/16   1150         bus
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307122 entries, 0 to 307121
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   dateCrawled         307122 non-null  object
#  1   name                307122 non-null  object
#  2   price               307122 non-null  int64
#  3   vehicleType         307122 non-null  object
#  4   yearOfRegistration  307122 non-null  int64
#  5   model               307122 non-null  object
#  6   kilometer           307122 non-null  int64
#  7   fuelType            307122 non-null  object
#  8   brand               307122 non-null  object
#  9   lastSeen            307122 non-null  object
# dtypes: int64(3), object(7)
# memory usage: 23.4+ MB

# %%
new_df['dateCrawled'] = pd.to_datetime(new_df['dateCrawled'])
new_df['lastSeen'] = pd.to_datetime(new_df['lastSeen'])
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307122 entries, 0 to 307121
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   dateCrawled         307122 non-null  datetime64[ns]
#  1   name                307122 non-null  object
#  2   price               307122 non-null  int64
#  3   vehicleType         307122 non-null  object
#  4   yearOfRegistration  307122 non-null  int64
#  5   model               307122 non-null  object
#  6   kilometer           307122 non-null  int64
#  7   fuelType            307122 non-null  object
#  8   brand               307122 non-null  object
#  9   lastSeen            307122 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(3), object(5)
# memory usage: 23.4+ MB

# %%
new_df
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-14 12:52:21                     Jeep_Grand_Cherokee_"Overland"
# 1      2016-03-17 16:54:04                                 GOLF_4_1_4__3TÜRER
# 2      2016-03-31 17:25:20                     Skoda_Fabia_1.4_TDI_PD_Classic
# 3      2016-04-04 17:36:23  BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...
# 4      2016-04-01 20:48:51                        Peugeot_206_CC_110_Platinum
# ...                    ...                                                ...
# 307117 2016-03-27 20:36:20                 Opel_Zafira_1.6_Elegance_TÜV_12/16
# 307118 2016-03-05 19:56:21              Smart_smart_leistungssteigerung_100ps
# 307119 2016-03-19 18:57:12                 Volkswagen_Multivan_T4_TDI_7DC_UY2
# 307120 2016-03-20 19:41:08                             VW_Golf_Kombi_1_9l_TDI
# 307121 2016-03-07 19:39:19       BMW_M135i_vollausgestattet_NP_52.720____Euro
#
# ...

# %%
new_df.to_csv('Resources/cleaned_df.csv',index = False)
